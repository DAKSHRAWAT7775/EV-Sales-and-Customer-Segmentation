# %%
import pandas as pd

# Load the datasets
ev_maker_place = pd.read_csv('C:/Users/daksh/OneDrive/Documents/Project/EV Sales and Customer Segmentaion/data/EV Maker by Place.csv')
ev_cat = pd.read_csv('C:/Users/daksh/OneDrive/Documents/Project/EV Sales and Customer Segmentaion/data/ev_cat_01-24.csv')
ev_sales_by_makers = pd.read_csv('C:/Users/daksh/OneDrive/Documents/Project/EV Sales and Customer Segmentaion/data/ev_sales_by_makers_and_cat_15-24.csv')
operational_pc = pd.read_csv('C:/Users/daksh/OneDrive/Documents/Project/EV Sales and Customer Segmentaion/data/OperationalPC.csv')
vehicle_class_registration = pd.read_csv('C:/Users/daksh/OneDrive/Documents/Project/EV Sales and Customer Segmentaion/data/Vehicle Class - All.csv')

# Display the first few rows of each dataset to understand their structure
print("EV Category Data:")
print(ev_cat.head())

print("\nEV Maker by Place Data:")
print(ev_maker_place.head())

print("\nEV Sales by Makers Data:")
print(ev_sales_by_makers.head())

print("\nOperational PC Data:")
print(operational_pc.head())

print("\nVehicle Class Registration Data:")
print(vehicle_class_registration.head())
# Out:
# EV Category Data:
#        Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 0         0                                0                    0
# 1  01/01/01                                0                    1
# 2  01/01/02                                0                    2
# 3  01/01/03                                0                    1
# 4  01/01/04                                0                    2
#
#    HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 0                    0                        0                    0
# 1                    0                        0                    9
# 2                    1                        0                  266
# 3                    2                        0                   35
# 4                    0                        1                   14
#
#    LIGHT MOTOR VEHICLE  LIGHT PASSENGER VEHICLE  MEDIUM GOODS VEHICLE  \
# ...

# %%
print("\nMissing Values in EV Category Data:")
print(ev_cat.isnull().sum())

print("\nMissing Values in EV Maker by Place Data:")
print(ev_maker_place.isnull().sum())

print("\nMissing Values in EV Sales by Makers Data:")
print(ev_sales_by_makers.isnull().sum())

print("\nMissing Values in Operational PC Data:")
print(operational_pc.isnull().sum())

print("\nMissing Values in Vehicle Class Registration Data:")
print(vehicle_class_registration.isnull().sum())
# Out:
# Missing Values in EV Category Data:
# Date                               0
# FOUR WHEELER (INVALID CARRIAGE)    0
# HEAVY GOODS VEHICLE                0
# HEAVY MOTOR VEHICLE                0
# HEAVY PASSENGER VEHICLE            0
# LIGHT GOODS VEHICLE                0
# LIGHT MOTOR VEHICLE                0
# LIGHT PASSENGER VEHICLE            0
# MEDIUM GOODS VEHICLE               0
# MEDIUM PASSENGER VEHICLE           0
# MEDIUM MOTOR VEHICLE               0
# OTHER THAN MENTIONED ABOVE         0
# THREE WHEELER(NT)                  0
# TWO WHEELER (INVALID CARRIAGE)     0
# THREE WHEELER(T)                   0
# TWO WHEELER(NT)                    0
# TWO WHEELER(T)                     0
# dtype: int64
#
# Missing Values in EV Maker by Place Data:
# EV Maker    0
# Place       0
# State       0
# dtype: int64
#
# Missing Values in EV Sales by Makers Data:
# Cat      0
# Maker    0
# 2015     0
# 2016     0
# 2017     0
# 2018     0
# 2019     0
# 2020     0
# 2021     0
# ...

# %%
# Example: Convert 'Date' column in ev_cat to datetime
ev_cat['Date'] = pd.to_datetime(ev_cat['Date'], errors='coerce')
ev_cat.head()
# Out:
# C:\Users\daksh\AppData\Local\Temp\ipykernel_3660\3507456792.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ev_cat['Date'] = pd.to_datetime(ev_cat['Date'], errors='coerce')
#         Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 0        NaT                                0                    0
# 1 2001-01-01                                0                    1
# 2 2002-01-01                                0                    2
# 3 2003-01-01                                0                    1
# 4 2004-01-01                                0                    2
#
#    HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 0                    0                        0                    0
# 1                    0                        0                    9
# ...

# %%
ev_cat = ev_cat.drop(0)
ev_cat = ev_cat.reset_index(drop=True)
ev_cat.head()
# Out:
#         Date  FOUR WHEELER (INVALID CARRIAGE)  HEAVY GOODS VEHICLE  \
# 0 2001-01-01                                0                    1
# 1 2002-01-01                                0                    2
# 2 2003-01-01                                0                    1
# 3 2004-01-01                                0                    2
# 4 2005-01-01                                0                    0
#
#    HEAVY MOTOR VEHICLE  HEAVY PASSENGER VEHICLE  LIGHT GOODS VEHICLE  \
# 0                    0                        0                    9
# 1                    1                        0                  266
# 2                    2                        0                   35
# 3                    0                        1                   14
# 4                    0                        0                   10
#
#    LIGHT MOTOR VEHICLE  LIGHT PASSENGER VEHICLE  MEDIUM GOODS VEHICLE  \
# 0                   15                        1                     0
# ...
